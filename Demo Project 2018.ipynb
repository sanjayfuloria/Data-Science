# %%
pwd
# Out:
# 'C:\\Python36\\Scripts'

# %%
import os
os.chdir('C:\Python36')

# %%
pwd
# Out:
# 'C:\\Python36'

# %%
import pandas as pd
import numpy as np

# %%
# import the pandas library
import pandas as pd
left = pd.DataFrame({
         'id':[1,2,3,4,5],
         'Name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'],
         'subject_id':['sub1','sub2','sub4','sub6','sub5']})
right = pd.DataFrame(
         {'id':[1,2,3,4,5],
         'Name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
         'subject_id':['sub2','sub4','sub3','sub6','sub5']})
print (left)
print (right)
# Out:
#    id    Name subject_id
# 0   1    Alex       sub1
# 1   2     Amy       sub2
# 2   3   Allen       sub4
# 3   4   Alice       sub6
# 4   5  Ayoung       sub5
#    id   Name subject_id
# 0   1  Billy       sub2
# 1   2  Brian       sub4
# 2   3   Bran       sub3
# 3   4  Bryce       sub6
# 4   5  Betty       sub5

# %%
import pandas as pd
left = pd.DataFrame({
         'id':[1,2,3,4,5],
         'Name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'],
         'subject_id':['sub1','sub2','sub4','sub6','sub5']})
right = pd.DataFrame(
         {'id':[1,2,3,4,5],
         'Name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
         'subject_id':['sub2','sub4','sub3','sub6','sub5']})
print (pd.merge(left,right,on='id'))
# Out:
#    id  Name_x subject_id_x Name_y subject_id_y
# 0   1    Alex         sub1  Billy         sub2
# 1   2     Amy         sub2  Brian         sub4
# 2   3   Allen         sub4   Bran         sub3
# 3   4   Alice         sub6  Bryce         sub6
# 4   5  Ayoung         sub5  Betty         sub5

# %% [markdown]
# Concatenating Objects

# %%
import pandas as pd
one = pd.DataFrame({
         'Name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'],
         'subject_id':['sub1','sub2','sub4','sub6','sub5'],
         'Marks_scored':[98,90,87,69,78]},
         index=[1,2,3,4,5])
two = pd.DataFrame({
         'Name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
         'subject_id':['sub2','sub4','sub3','sub6','sub5'],
         'Marks_scored':[89,80,79,97,88]},
         index=[1,2,3,4,5])
print (pd.concat([one,two]))
# Out:
#      Name subject_id  Marks_scored
# 1    Alex       sub1            98
# 2     Amy       sub2            90
# 3   Allen       sub4            87
# 4   Alice       sub6            69
# 5  Ayoung       sub5            78
# 1   Billy       sub2            89
# 2   Brian       sub4            80
# 3    Bran       sub3            79
# 4   Bryce       sub6            97
# 5   Betty       sub5            88

# %% [markdown]
# Print the current date and time

# %%
import pandas as pd
print (pd.datetime.now())
# Out:
# 2018-12-10 16:17:07.592347

# %%
import pandas as pd
print (pd.Timestamp('2018-12-10'))
# Out:
# 2018-12-10 00:00:00

# %%
import pandas as pd

print (pd.Timedelta(6,unit='h'))
# Out:
# 0 days 06:00:00

# %% [markdown]
# Operations
# You can operate on Series/ DataFrames and construct timedelta64[ns] Series through subtraction operations on datetime64[ns] Series, or Timestamps.
#
# Let us now create a DataFrame with Timedelta and datetime objects and perform some arithmetic operations on it −

# %%
import pandas as pd

s = pd.Series(pd.date_range('2012-1-1', periods=3, freq='D'))
td = pd.Series([ pd.Timedelta(days=i) for i in range(3) ])
df = pd.DataFrame(dict(A = s, B = td))
print (df)
# Out:
#            A      B
# 0 2012-01-01 0 days
# 1 2012-01-02 1 days
# 2 2012-01-03 2 days

# %%
import pandas as pd

s = pd.Series(pd.date_range('2012-1-1', periods=3, freq='D'))
td = pd.Series([ pd.Timedelta(days=i) for i in range(3) ])
df = pd.DataFrame(dict(A = s, B = td))
df['C']=df['A']+df['B']
df['D']=df['C']+df['B']
print (df)
# Out:
#            A      B          C          D
# 0 2012-01-01 0 days 2012-01-01 2012-01-01
# 1 2012-01-02 1 days 2012-01-03 2012-01-04
# 2 2012-01-03 2 days 2012-01-05 2012-01-07

# %%
import pandas as pd
import numpy as np

cat = pd.Categorical(["a", "c", "c", np.nan], categories=["b", "a", "c"])
df = pd.DataFrame({"cat":cat, "s":["a", "c", "c", np.nan]})
print (df.describe())

print (df["cat"].describe())
# Out:
#        cat  s
# count    3  3
# unique   2  2
# top      c  c
# freq     2  2
# count     3
# unique    2
# top       c
# freq      2
# Name: cat, dtype: object

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.randn(10,4),index=pd.date_range('1/1/2000',
   periods=10), columns=list('ABCD'))
df.plot()

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])
df.plot.bar()

# %%
import pandas as pd
df = pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])
df.plot.bar(stacked=True)

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])

df.plot.barh(stacked=True)

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({'a':np.random.randn(1000)+1,'b':np.random.randn(1000),'c':
np.random.randn(1000) - 1}, columns=['a', 'b', 'c'])

df.plot.hist(bins=20)

# %%
import pandas as pd
import numpy as np

df=pd.DataFrame({'a':np.random.randn(1000)+1,'b':np.random.randn(1000),'c':
np.random.randn(1000) - 1}, columns=['a', 'b', 'c'])

df.diff().hist(bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000231CCFFBB00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000231CD04FEF0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000231CD07E4A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000231CD0A5A20>]],
#       dtype=object)

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
print(df)
df.plot.area()
# Out:
#           a         b         c         d
# 0  0.765606  0.792392  0.271372  0.826176
# 1  0.550299  0.520423  0.366025  0.217096
# 2  0.204400  0.157678  0.005800  0.563902
# 3  0.144469  0.937262  0.291041  0.901630
# 4  0.247459  0.589887  0.001023  0.737414
# 5  0.007330  0.077840  0.051593  0.609685
# 6  0.421529  0.809698  0.174010  0.252383
# 7  0.922394  0.088520  0.502747  0.368976
# 8  0.965148  0.062253  0.245987  0.892801
# 9  0.794478  0.019968  0.727264  0.584345

# %%
pwd
# Out:
# 'C:\\Python36\\Scripts'

# %%
import os
os.chdir('C:\Python36')

# %%
import pandas as pd
df=pd.read_csv("temp.csv")
print (df)
# Out:
#    S.No    Name  Age       City  Salary
# 0     1     Tom   28    Toronto   20000
# 1     2     Lee   32   HongKong    3000
# 2     3  Steven   43   Bay Area    8300
# 3     4     Ram   38  Hyderabad    3900

# %% [markdown]
# SQL Operations using pandas

# %%
import pandas as pd
url = 'https://raw.github.com/pandasdev/
pandas/master/pandas/tests/data/tips.csv'
tips=pd.read_csv(url)
print tips.head()
# Out:
#   File "<ipython-input-21-7470e36c26a3>", line 2
#     url = 'https://raw.github.com/pandasdev/
#                                             ^
# SyntaxError: EOL while scanning string literal

# %%
import urllib.request
with urllib.request.urlopen('https://github.com/mono0926/python-for-data-analytics/blob/master/ch08/tips.csv') as response:
     html = response.read()
print(html)
# Out:
# b'\n\n\n\n\n\n<!DOCTYPE html>\n<html lang="en">\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://assets-cdn.github.com">\n  <link rel="dns-prefetch" href="https://avatars0.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars1.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars2.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars3.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n\n\n\n  <link crossorigin="anonymous" media="all" integrity="sha512-lLo2nlsdl+bHLu6PGvC2j3wfP45RnK4wKQLiPnCDcuXfU38AiD+JCdMywnF3WbJC1jaxe3lAI6AM4uJuMFBLEw==" rel="stylesheet" href="https://assets-cdn.github.com/assets/frameworks-08fc49d3bd2694c870ea23d0906f3610.css" />\n  <link crossorigin="anonymous" media="all" integrity="sha512-y09vkWQRwHShJ+eX0P1pRG6UkOVMj6aA1pim1qfk2dCvGZBCIGW8KtaZq4qEXoKXs7SFFOV6LArzgfEP8k1URA==" rel="stylesheet" href="https://assets-cdn.github.com/assets/github-69450ccb57439ae54c85cfecedfc7480.css" />\n  \n  \n  <link crossorigin="anonymous" media="all" integrity="sha512-PcJMPDRp7jbbEAmTk9kaL2kRQqg69QZ26WsZf07xsPyaipKsi3wVG0805PZNYXxotPDAliKKFvNSQPhD8fp1FQ==" rel="stylesheet" href="https://assets-cdn.github.com/assets/site-50c740d9290419d070dd6213a7cd03b5.css" />\n  \n  \n\n  <meta name="viewport" content="width=device-width">\n  \n  <title>python-for-data-analytics/tips.csv at master \xc2\xb7 mono0926/python-for-data-analytics \xc2\xb7 GitHub</title>\n    <meta name="description" content="Contribute to mono0926/python-for-data-analytics development by creating an account on GitHub.">\n    <link rel="search" type="application/opensearchdescription+xml" href="/opensearch.xml" title="GitHub">\n  <link rel="fluid-icon" href="https://github.com/fluidicon.png" title="GitHub">\n  <meta property="fb:app_id" content="1401488693436528">\n\n    \n    <meta property="og:image" content="https://avatars2.githubusercontent.com/u/1255062?s=400&amp;v=4" /><meta property="og:site_name" content="GitHub" /><meta property="og:type" content="object" /><meta property="og:title" content="mono0926/python-for-data-analytics" /><meta property="og:url" content="https://github.com/mono0926/python-for-data-analytics" /><meta property="og:description" content="Contribute to mono0926/python-for-data-analytics development by creating an account on GitHub." />\n\n  <link rel="assets" href="https://assets-cdn.github.com/">\n  \n  <meta name="pjax-timeout" content="1000">\n  \n  <meta name="request-id" content="59B1:2323:5544583:7DFE9E8:5C0F7AD1" data-pjax-transient>\n\n\n  \n\n  <meta name="selected-link" value="repo_source" data-pjax-transient>\n\n      <meta name="google-site-verification" content="KT5gs8h0wvaagLKAVWq8bbeNwnZZK1r1XQysX3xurLU">\n    <meta name="google-site-verification" content="ZzhVyEFwb7w3e0-uOTltm8Jsck2F5StVihD0exw2fsA">\n    <meta name="google-site-verification" content="GXs5KoUUkNCoaAZn7wPN-t01Pywp9M3sEjnt_3_ZWPc">\n\n  <meta name="octolytics-host" content="collector.githubapp.com" /><meta name="octolytics-app-id" content="github" /><meta name="octolytics-event-url" content="https://collector.githubapp.com/github-external/browser_event" /><meta name="octolytics-dimension-request_id" content="59B1:2323:5544583:7DFE9E8:5C0F7AD1" /><meta name="octolytics-dimension-region_edge" content="iad" /><meta name="octolytics-dimension-region_render" content="iad" />\n<meta name="analytics-location" content="/&lt;user-name&gt;/&lt;repo-name&gt;/blob/show" data-pjax-transient="true" />\n\n\n\n    <meta name="google-analytics" content="UA-3769691-2">\n\n\n<meta class="js-ga-set" name="dimension1" content="Logged Out">\n\n\n\n  \n\n      <meta name="hostname" content="github.com">\n    <meta name="user-login" content="">\n\n      <meta name="expected-hostname" content="github.com">\n    <meta name="js-proxy-site-detection-payload" conte ...

# %%
import pandas as pd
import io
import requests
url="https://raw.githubusercontent.com/mono0926/python-for-data-analytics/master/ch08/tips.csv"
s=requests.get(url).content
tips=pd.read_csv(io.StringIO(s.decode('utf-8')))
print(tips.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# Using the SQL like feature

# %%
import pandas as pd
import io
import requests
url="https://raw.githubusercontent.com/mono0926/python-for-data-analytics/master/ch08/tips.csv"
s=requests.get(url).content
tips=pd.read_csv(io.StringIO(s.decode('utf-8')))
print (tips[['total_bill', 'tip', 'smoker', 'time']].head(5))
# Out:
#    total_bill   tip smoker    time
# 0       16.99  1.01     No  Dinner
# 1       10.34  1.66     No  Dinner
# 2       21.01  3.50     No  Dinner
# 3       23.68  3.31     No  Dinner
# 4       24.59  3.61     No  Dinner

# %% [markdown]
# Where clause

# %%
import pandas as pd
import io
import requests
url="https://raw.githubusercontent.com/mono0926/python-for-data-analytics/master/ch08/tips.csv"
s=requests.get(url).content
tips=pd.read_csv(io.StringIO(s.decode('utf-8')))
print (tips[tips['time'] == 'Dinner'].head(5))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# Group By

# %%
import pandas as pd
import io
import requests
url="https://raw.githubusercontent.com/mono0926/python-for-data-analytics/master/ch08/tips.csv"
s=requests.get(url).content
tips=pd.read_csv(io.StringIO(s.decode('utf-8')))
print(tips.groupby('sex').size())
# Out:
# sex
# Female     87
# Male      157
# dtype: int64

# %% [markdown]
# Top N Rows

# %%
import pandas as pd
import io
import requests
url="https://raw.githubusercontent.com/mono0926/python-for-data-analytics/master/ch08/tips.csv"
s=requests.get(url).content
tips=pd.read_csv(io.StringIO(s.decode('utf-8')))
print(tips.head(5))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import pandas as pd
import io
import requests
url="https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
s=requests.get(url).content
c=pd.read_csv(io.StringIO(s.decode('utf-8')))
print(c.head())
# Out:
#     Country  Region
# 0   Algeria  AFRICA
# 1    Angola  AFRICA
# 2     Benin  AFRICA
# 3  Botswana  AFRICA
# 4   Burkina  AFRICA
